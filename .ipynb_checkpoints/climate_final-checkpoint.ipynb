# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
columns = inspector.get_columns('measurement')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
columns = inspector.get_columns('station')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
same_station = session.query(Station.station, Measurement.station).\
filter(Station.station == Measurement.station).all()

# %%
precip = [Station.station, Station.name, Station.latitude, Station.longitude, Station.elevation, Measurement.date, Measurement.prcp]

same_station = session.query(*precip).filter(Measurement.station == Station.station).all()

# %%
same_station_df = pd.DataFrame(same_station)

# %%
same_station_df1 = same_station_df.drop(["station", "latitude", "longitude", "elevation"], axis = 1)

# %%
same_station_df1 = same_station_df1.reset_index(drop=True)

# %%
same_station_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2724 entries, 0 to 2723
# Data columns (total 3 columns):
# name    2724 non-null object
# date    2724 non-null object
# prcp    2685 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 85.1+ KB

# %%
same_station_df1 = same_station_df1.loc[same_station_df1["name"] == "WAIKIKI 717.2, HI US", :]

# %%
same_station_df1.sort_values(['name','date'])
# Out:
#                       name        date  prcp
# 0     WAIKIKI 717.2, HI US  2010-01-01  0.08
# 1     WAIKIKI 717.2, HI US  2010-01-02  0.00
# 2     WAIKIKI 717.2, HI US  2010-01-03  0.00
# 3     WAIKIKI 717.2, HI US  2010-01-04  0.00
# 4     WAIKIKI 717.2, HI US  2010-01-06   NaN
# 5     WAIKIKI 717.2, HI US  2010-01-07  0.06
# 6     WAIKIKI 717.2, HI US  2010-01-08  0.00
# 7     WAIKIKI 717.2, HI US  2010-01-09  0.00
# 8     WAIKIKI 717.2, HI US  2010-01-10  0.00
# 9     WAIKIKI 717.2, HI US  2010-01-11  0.01
# 10    WAIKIKI 717.2, HI US  2010-01-12  0.00
# 11    WAIKIKI 717.2, HI US  2010-01-14  0.00
# 12    WAIKIKI 717.2, HI US  2010-01-15  0.00
# 13    WAIKIKI 717.2, HI US  2010-01-16  0.00
# 14    WAIKIKI 717.2, HI US  2010-01-17  0.00
# 15    WAIKIKI 717.2, HI US  2010-01-18  0.00
# 16    WAIKIKI 717.2, HI US  2010-01-19  0.00
# 17    WAIKIKI 717.2, HI US  2010-01-20  0.00
# 18    WAIKIKI 717.2, HI US  2010-01-21  0.00
# 19    WAIKIKI 717.2, HI US  2010-01-22  0.00
# ...

# %%
same_station_df2 = same_station_df1.tail(365)

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results

# Calculate the date 1 year ago from today

# Perform a query to retrieve the data and precipitation scores

# Save the query results as a Pandas DataFrame and set the index to the date column

# Sort the dataframe by date

# Use Pandas Plotting with Matplotlib to plot the data

# Rotate the xticks for the dates

# %%
same_station_df2.plot.line(x="date", y="prcp")
plt.title("Waikiki Daily Rainfall (in.)")
plt.xlabel("Date")
plt.ylabel("Inches of Rain")
# Out:
# Text(0,0.5,'Inches of Rain')

# %% [markdown]
# ![precipitation](Images/precipitation.png)

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
same_station_df2.describe()
# Out:
#              prcp
# count  363.000000
# mean     0.045868
# std      0.188743
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.020000
# max      2.620000

# %%
# What are the most active stations?
# List the stations and the counts in descending order.
# How many stations are available in this dataset?

count = same_station_df["name"].value_counts()
count
# Out:
# WAIHEE 837.5, HI US                       2772
# WAIKIKI 717.2, HI US                      2724
# KANEOHE 838.1, HI US                      2709
# WAIMANALO EXPERIMENTAL FARM, HI US        2669
# MANOA LYON ARBO 785.2, HI US              2612
# KUALOA RANCH HEADQUARTERS 886.9, HI US    2202
# HONOLULU OBSERVATORY 702.2, HI US         1979
# PEARL CITY, HI US                         1372
# UPPER WAHIAWA 874.3, HI US                 511
# Name: name, dtype: int64

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature most active station?

# sel = [Station.name, 
#        func.min(Measurement.prcp), 
#        func.max(Measurement.prcp), 
#        func.avg(Measurement.prcp)]

# station_review = session.query(*sel).\
#     filter(func.strftime("%m", Dow.date) == "05").\
#     group_by(Dow.stock).\
#     order_by(Dow.stock).all()
# may_averages
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Write a function called `calc_temps` that will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
# Out:
# 62.0 68.36585365853658 74.0

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
# Calculate the rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
# Out:
# [('USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4, 0.31), ('USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9, 0.25), ('USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6, 0.1), ('USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6, 0.060000000000000005), ('USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9, 0.0), ('USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0, 0.0), ('USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9, 0.0), ('USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0, 0.0), ('USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5, 0.0)]

# %% [markdown]
# ## Optional Challenge Assignment

# %%
# Part 2

# %%
# 1. import Flask
from flask import Flask, jsonify
import numpy as np

# 2. Create an app, being sure to pass __name__
app = Flask(__name__)

# %%
# 3. Define what to do when a user hits the index route
@app.route("/api/v1.0/precipitation")

def precip():
    results = session.query(*precip).filter(Measurement.station == Station.station).all()
    
    2017_results = []
    for measurement in results:
        measurement_dict = {}
        measurement_dict["date"] = Measurement.date
